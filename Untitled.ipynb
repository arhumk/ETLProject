# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.yelp.com/search?find_desc=&find_loc=east+harlem&ns=1'
browser.visit(url)

# %%
def click_next(browser, tryNo=0):
    if tryNo > 20:
        raise Exception("Nope")
    try:
        browser.find_by_text("Next").last.click()
    except:
        click_next(browser, tryNo=tryNo+1)

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://www.yelp.com/search?find_desc=&find_loc=east+harlem&ns=1'
browser.visit(url)

price_ranges=[]

for x in range(1, 12):

    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    price_levels = soup.\
        find_all('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f priceRange__373c0__2DY87 text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_ text-bullet--after__373c0__1ZHaA")
    
    
    
    for price_level in price_levels:
        print('page:', x, '-------------')
        print(price_level.text)
        price_ranges.append(price_level.text)
        
    
    
    
    browser.is_text_present('Next', wait_time=10)
    click_next(browser)
# Out:
# page: 1 -------------
# $$
# page: 1 -------------
# $
# page: 1 -------------
# $$
# page: 1 -------------
# $$$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 1 -------------
# $$$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 1 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $
# page: 2 -------------
# $$
# page: 2 -------------
# $$$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $$$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 2 -------------
# $$
# page: 3 -------------
# $$
# page: 3 -------------
# $
# page: 3 -------------
# $$
# page: 3 -------------
# $$$
# page: 3 -------------
# $
# page: 3 -------------
# $$
# page: 3 -------------
# $$
# page: 3 -------------
# $$
# ...

# %%
len(price_ranges)
# Out:
# 113

# %%
price_ranges[13:]
# Out:
# ['$$',
#  '$',
#  '$$',
#  '$$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$$$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$$$',
#  '$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$',
#  '$$',
#  '$',
#  '$',
#  '$$',
#  '$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$',
#  '$$',
#  '$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$',
#  '$$']

# %%
price_ranges=price_ranges[13:]

# %%
price_ranges=price_ranges[:90]

# %%
len(price_ranges)
# Out:
# 90

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://www.yelp.com/search?find_desc=&find_loc=east+harlem&ns=1'
browser.visit(url)

burroughs_names=[]
for x in range(1, 12):
    
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    burroughs=soup.\
        find_all("div",class_="lemon--div__373c0__1mboc u-space-b1 border-color--default__373c0__2oFDT")
    
    
    for burrough in burroughs:
        print('page:', x, '-------------')
        print(burrough.text)
        burroughs_names.append(burrough.text)
        
    
    browser.is_text_present('Next', wait_time=10)
    click_next(browser)
    
    #try:
        #browser.click_link_by_href(href="/search?find_loc=east%20harlem&start=20")
          
    #except:
        #print("Scraping Paused")
# Out:
# page: 1 -------------
# Upper West Side
# page: 1 -------------
# Harlem
# page: 1 -------------
# Grab-and-go
# page: 1 -------------
# Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# Harlem
# page: 1 -------------
# East Harlem
# page: 1 -------------
# Harlem
# page: 1 -------------
# Greenwich Village
# page: 2 -------------
# Upper West Side
# page: 2 -------------
# Harlem
# page: 2 -------------
# Grab-and-go
# page: 2 -------------
# Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# Harlem
# page: 2 -------------
# East Harlem
# page: 2 -------------
# Harlem
# ...

# %%
burroughs_names
# Out:
# ['Upper West Side',
#  'Harlem',
#  'Grab-and-go',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'Harlem',
#  'Greenwich Village',
#  'Upper West Side',
#  'Harlem',
#  'Grab-and-go',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'Harlem',
#  'Greenwich Village',
#  'Koreatown',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'Central Park',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'Happy hour specials',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'Manhattan Valley',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'Harlem',
#  'East Harlem',
#  'East Harlem',
#  'East Harlem',
# ...

# %%
burroughs_names=burroughs_names[14:]

# %%
burroughs_names.remove("")

# %%
len(burroughs_names)
# Out:
# 102

# %%
burroughs_names=burroughs_names[:90]

# %%
len(burroughs_names)
# Out:
# 90

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://www.yelp.com/search?find_desc=&find_loc=east+harlem&ns=1'
browser.visit(url)

restaurant_names=[]

for x in range(1, 12):
    
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    rest_names=soup.find_all("h3",class_="lemon--h3__373c0__sQmiG heading--h3__373c0__1n4Of alternate__373c0__1uacp")

    for rest_name in rest_names:
        print(rest_name.text)
        restaurant_names.append(rest_name.text)

    browser.is_text_present('Next', wait_time=10)
    click_next(browser)
# Out:
# Alice’s Tea Cup
# Sugar Hill Cafe
# 1. Amy Ruth’s
# 2. Ricardo Steak House
# 3. Cascalote Latin Bistro
# 4. Earl’s Beer & Cheese
# 5. Patsy’s Pizzeria
# 6. El Kallejon
# 7. Serengeti Teas & Spices
# 8. Red Rooster Harlem
# 9. Cafe Ollin
# 10. Levain Bakery
# Banter
# Alice’s Tea Cup
# Sugar Hill Cafe
# 1. Amy Ruth’s
# 2. Ricardo Steak House
# 3. Cascalote Latin Bistro
# 4. Earl’s Beer & Cheese
# 5. Patsy’s Pizzeria
# 6. El Kallejon
# 7. Serengeti Teas & Spices
# 8. Red Rooster Harlem
# 9. Cafe Ollin
# 10. Levain Bakery
# Banter
# Ayza Wine & Chocolate Bar
# 11. La Shuk
# 12. Dear Mama Coffee
# 13. Seasoned Vegan
# 14. The Conservatory Garden
# 15. Central Park
# 16. Mountain Bird
# 17. Tres Leches Cafe
# 18. Sylvia’s Restaurant
# 19. Santiago’s Beer Garden
# 20. Amor Cubano
# 21. Malii
# 22. Lido
# 23. Joy Burger Bar
# 24. Rao’s
# 25. Taco Mix
# 26. Love Cafe
# 27. Sottocasa Pizzeria - Harlem
# 28. Da Capo
# 29. Nocciola Ristorante
# 30. Absolute Bagels
# 31. Lolo’s Seafood Shack
# ...

# %%
restaurant_names
# Out:
# ['Alice’s Tea Cup',
#  'Sugar Hill Cafe',
#  '1.\xa0Amy Ruth’s',
#  '2.\xa0Ricardo Steak House',
#  '3.\xa0Cascalote Latin Bistro',
#  '4.\xa0Earl’s Beer & Cheese',
#  '5.\xa0Patsy’s Pizzeria',
#  '6.\xa0El Kallejon',
#  '7.\xa0Serengeti Teas & Spices',
#  '8.\xa0Red Rooster Harlem',
#  '9.\xa0Cafe Ollin',
#  '10.\xa0Levain Bakery',
#  'Banter',
#  'Alice’s Tea Cup',
#  'Sugar Hill Cafe',
#  '1.\xa0Amy Ruth’s',
#  '2.\xa0Ricardo Steak House',
#  '3.\xa0Cascalote Latin Bistro',
#  '4.\xa0Earl’s Beer & Cheese',
#  '5.\xa0Patsy’s Pizzeria',
#  '6.\xa0El Kallejon',
#  '7.\xa0Serengeti Teas & Spices',
#  '8.\xa0Red Rooster Harlem',
#  '9.\xa0Cafe Ollin',
#  '10.\xa0Levain Bakery',
#  'Banter',
#  'Ayza Wine & Chocolate Bar',
#  '11.\xa0La Shuk',
#  '12.\xa0Dear Mama Coffee',
#  '13.\xa0Seasoned Vegan',
#  '14.\xa0The Conservatory Garden',
#  '15.\xa0Central Park',
#  '16.\xa0Mountain Bird',
#  '17.\xa0Tres Leches Cafe',
#  '18.\xa0Sylvia’s Restaurant',
#  '19.\xa0Santiago’s Beer Garden',
# ...

# %%
restaurant_names=restaurant_names[15:]

# %%
restaurant_names.remove("Ayza Wine & Chocolate Bar")

# %%
len(restaurant_names)
# Out:
# 90

# %%
import pandas as pd

# %%
df=pd.DataFrame({"Restaurant Name": restaurant_names,
                "Price Ranges": price_ranges,
                "Burrough": burroughs_names
               })

# %%
df
# Out:
#                          Restaurant Name Price Ranges           Burrough
# 0                          1. Amy Ruth’s           $$    Upper West Side
# 1                 2. Ricardo Steak House            $             Harlem
# 2              3. Cascalote Latin Bistro           $$             Harlem
# 3                4. Earl’s Beer & Cheese          $$$        East Harlem
# 4                    5. Patsy’s Pizzeria           $$        East Harlem
# 5                         6. El Kallejon           $$        East Harlem
# 6             7. Serengeti Teas & Spices           $$        East Harlem
# 7                  8. Red Rooster Harlem           $$        East Harlem
# 8                          9. Cafe Ollin           $$        East Harlem
# 9                      10. Levain Bakery          $$$             Harlem
# 10                           11. La Shuk           $$        East Harlem
# 11                  12. Dear Mama Coffee           $$             Harlem
# ...
